# %%
# imports
import requests
import urllib
import pandas as pd
import json
import time
import random
import base64

# %%
# load data
df = pd.read_csv("data.csv")

# keep only title and aristic column
df_blankSongs = df[['Title', 'Artist', 'Genre']]
print(len(df_blankSongs.loc[df_blankSongs['Top Year']==2021]))


# # keep only records with blank genres (we'll be filling them in)
# df_blankSongs = df_blankSongs.loc[df_blankSongs['Genre'].isnull()]

# # convert from df to array
# blankSongs = df_blankSongs.to_dict('records')
# print(blankSongs)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#
# /usr/local/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.7/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Top Year'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /var/folders/j7/0101smyj0vq85m09znmstz600000gp/T/ipykernel_11842/209387784.py in <module>
#       4 # keep only title and aristic column
#       5 df_blankSongs = df[['Title', 'Artist', 'Genre']]
# ----> 6 print(len(df_blankSongs.loc[df_blankSongs['Top Year']==2021]))
#       7
#       8
#
# /usr/local/lib/python3.7/site-packages/pandas/core/frame.py in __getitem__(self, key)
#    3456             if self.columns.nlevels > 1:
#    3457                 return self._getitem_multilevel(key)
# -> 3458             indexer = self.columns.get_loc(key)
#    3459             if is_integer(indexer):
#    3460                 indexer = [indexer]
#
# /usr/local/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
# -> 3363                 raise KeyError(key) from err
#    3364
#    3365         if is_scalar(key) and isna(key) and not self.hasnans:
#
# KeyError: 'Top Year'

# %%
# save variables
url = "https://api.spotify.com/v1/"
authToken = 'BQA757GlKwZQKUeCdYkZsrwk33efo295n1HFSJoiXngzW9VZRLau0Ys-7RV2OQcjE9j8RfXWL-o8JkJp5rJKG7T0JdT221ap1x7nZA_f6HqujPONoYdV8UvwK6WYQ0kYgPzI7crbn1bQTGqqV-LkpsxssufNiUNAOM0RQRAFMqw7iRAjCsRZiw'
getHeader = {
    'Accept': 'application/json',
    'Content-Type': 'application/json',
    'Authorization': 'Bearer ' + authToken
}

# %% [markdown]
# # Get Track IDs & genres
# URL: https://api.spotify.com/v1/search

# %%
uri = url + "search"
uri2 = url + "artists/"
pairedSongs = []
failedSongs = []

for song in blankSongs:
    title = song['Title']
    artist = song['Artist']
    
    params = {
        'query': title,
        'type': 'track',
        'limit': 1,
        'offset': 0
    }
    
    response = requests.get(uri, headers=getHeader, params=params)

    
    if len(json.loads(response.content)['tracks']['items']) > 0:
        print(title, artist, json.loads(response.content)['tracks']['items'][0]['id'])
        songId = json.loads(response.content)['tracks']['items'][0]['id']
        artistId = json.loads(response.content)['tracks']['items'][0]['album']['artists'][0]['id']
        
        # get artist now
        response2 = requests.get(uri2 + artistId, headers=getHeader)
        
        if len(json.loads(response2.content.decode('utf-8'))["genres"]) > 0:
            genre = json.loads(response2.content.decode('utf-8'))["genres"][0]
        else:
            genre = "n/a"
        
        # append new object
        songObject = {
            'title': title, 
            'songId': songId, 
            'artistId': artistId,
            'genre': genre
        }
        print(songObject)
        
        pairedSongs.append(songObject)
        
    else:
        failedSongs.append({'title': title, 'artist': artist})
# Out:
# NOT SOBER (feat. Polo G & Stunna Gambino) The Kid LAROI 1JXBNvlDEl2epKSJ9EOgKX
# {'title': 'NOT SOBER (feat. Polo G & Stunna Gambino)', 'songId': '1JXBNvlDEl2epKSJ9EOgKX', 'artistId': '2tIP7SsRs7vjIcLrU85W8J', 'genre': 'australian hip hop'}
# Build a Bitch Bella Poarch 7BoobGhD4x5K96Me0hqC8Q
# {'title': 'Build a Bitch', 'songId': '7BoobGhD4x5K96Me0hqC8Q', 'artistId': '26cMerAxjx9GedFt0lMDjm', 'genre': 'modern alternative pop'}
# Tiroteo - Remix Marc Seguí, Rauw Alejandro, Pol Granch 4OwhwvKESFtuu06dTgct7i
# {'title': 'Tiroteo - Remix', 'songId': '4OwhwvKESFtuu06dTgct7i', 'artistId': '5FQ8tBUtIamA2hRtatrYUF', 'genre': 'spanish pop'}
# Meu Pedaço de Pecado João Gomes 2kJRlOyrxsy7Ot3c5TZ8Q6
# {'title': 'Meu Pedaço de Pecado', 'songId': '2kJRlOyrxsy7Ot3c5TZ8Q6', 'artistId': '4JNo6Q5KdcRf1vtSX9mB0S', 'genre': 'arrocha'}
# Don't Start Now Dua Lipa 3PfIrDoz19wz7qK7tYeu62
# {'title': "Don't Start Now", 'songId': '3PfIrDoz19wz7qK7tYeu62', 'artistId': '6M2wZ9GZgrQXHCFfjv46we', 'genre': 'dance pop'}
# Dinero Trinidad Cardona 3ggtU1ZOKO8ZNiqPNyXGcm
# {'title': 'Dinero', 'songId': '3ggtU1ZOKO8ZNiqPNyXGcm', 'artistId': '4wP1kxjUsc9IR4Iy2smL7o', 'genre': 'n/a'}
# Love Again Dua Lipa 6uSQtbjopwwgwUWrLQwOEn
# {'title': 'Love Again', 'songId': '6uSQtbjopwwgwUWrLQwOEn', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# In Da Getto J Balvin, Skrillex 63aj87TQG6F3RVO5nbG2VQ
# {'title': 'In Da Getto', 'songId': '63aj87TQG6F3RVO5nbG2VQ', 'artistId': '1vyhD5VmyZ7KMfW5gqLgo5', 'genre': 'reggaeton'}
# No Me Conocen (Remix) [con DUKI, Rei & Tiago PZK] BANDIDO 7COGuXyTr12KvdaYXMqheC
# {'title': 'No Me Conocen (Remix) [con DUKI, Rei & Tiago PZK]', 'songId': '7COGuXyTr12KvdaYXMqheC', 'artistId': '7CSpCpNGTK9589bTi44SzE', 'genre': 'concurso de talentos argentino'}
# París Ingratax 7712gjoih4QoDbXpljEk21
# {'title': 'París', 'songId': '7712gjoih4QoDbXpljEk21', 'artistId': '06HL4z0CvFAxyc27GXpf02', 'genre': 'pop'}
# Sunflower - Spider-Man: Into the Spider-Verse Post Malone, Swae Lee 3KkXRkHbMCARz0aVfEt68P
# {'title': 'Sunflower - Spider-Man: Into the Spider-Verse', 'songId': '3KkXRkHbMCARz0aVfEt68P', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Hold On Justin Bieber 5vjLSffimiIP26QG5WcN2K
# {'title': 'Hold On', 'songId': '5vjLSffimiIP26QG5WcN2K', 'artistId': '5D3muNJhYYunbRkh3FKgX0', 'genre': 'acoustic pop'}
# Aquelas Coisas João Gomes 0FqVtQxRD3HsPltldG5v5M
# {'title': 'Aquelas Coisas', 'songId': '0FqVtQxRD3HsPltldG5v5M', 'artistId': '4JNo6Q5KdcRf1vtSX9mB0S', 'genre': 'arrocha'}
# Não, Não Vou Mari Fernandez 3jSG8oE8doxDxmpe5GlFee
# {'title': 'Não, Não Vou', 'songId': '3jSG8oE8doxDxmpe5GlFee', 'artistId': '0BHm7qbh3ENxvXzkQAG7MP', 'genre': 'arrocha'}
# Como Si No Importara Emilia, Duki 1GYJpuLq41vEVKXiHGEY9j
# {'title': 'Como Si No Importara', 'songId': '1GYJpuLq41vEVKXiHGEY9j', 'artistId': '0AqlFI0tz2DsEoJlKSIiT9', 'genre': 'pop argentino'}
# Se For Amor João Gomes, Vitor Fernandes 5F2xRvRFkxDvqdFtUNAEyw
# {'title': 'Se For Amor', 'songId': '5F2xRvRFkxDvqdFtUNAEyw', 'artistId': '4JNo6Q5KdcRf1vtSX9mB0S', 'genre': 'arrocha'}
# Ramenez la coupe à la maison Vegedream 1m0UFnuTktOkksvjbF9z0m
# {'title': 'Ramenez la coupe à la maison', 'songId': '1m0UFnuTktOkksvjbF9z0m', 'artistId': '4eYnorQRhVHT2KBl2UyHHd', 'genre': 'francoton'}
# 34+35 Ariana Grande 6Im9k8u9iIzKMrmV7BWtlF
# {'title': '34+35', 'songId': '6Im9k8u9iIzKMrmV7BWtlF', 'artistId': '66CXWjxzNUsdJxJ2JdwvnR', 'genre': 'dance pop'}
# bad guy Billie Eilish 2Fxmhks0bxGSBdJ92vM42m
# {'title': 'bad guy', 'songId': '2Fxmhks0bxGSBdJ92vM42m', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# As the World Caves In Sarah Cothran 2xXNLutYAOELYVObYb1C1S
# {'title': 'As the World Caves In', 'songId': '2xXNLutYAOELYVObYb1C1S', 'artistId': '3kft86DbqCNr7rjq3pEj0G', 'genre': 'gen z singer-songwriter'}
# Chosen (feat. Ty Dolla $ign) Blxst, Tyga 1dIWPXMX4kRHj6Dt2DStUQ
# {'title': 'Chosen (feat. Ty Dolla $ign)', 'songId': '1dIWPXMX4kRHj6Dt2DStUQ', 'artistId': '4qXC0i02bSFstECuXP2ZpL', 'genre': 'pop rap'}
# Lost Cause Billie Eilish 4191RXFPa7Ge9XkA4cWlna
# {'title': 'Lost Cause', 'songId': '4191RXFPa7Ge9XkA4cWlna', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# Dick (feat. Doja Cat) StarBoi3 3nY8AqaMNNHHLYV4380ol0
# {'title': 'Dick (feat. Doja Cat)', 'songId': '3nY8AqaMNNHHLYV4380ol0', 'artistId': '2WgfkM8S11vg4kxLgDY3F5', 'genre': 'n/a'}
# malibu sangiovanni 1UZOjK1BwmwWU14Erba9CZ
# {'title': 'malibu', 'songId': '1UZOjK1BwmwWU14Erba9CZ', 'artistId': '5YGY8feqx7naU7z4HrwZM6', 'genre': 'dance pop'}
# Wellerman - Sea Shanty / 220 KID x Billen Ted Remix Nathan Evans 3iw6V4LH7yPj1ESORX9RIN
# {'title': 'Wellerman - Sea Shanty / 220 KID x Billen Ted Remix', 'songId': '3iw6V4LH7yPj1ESORX9RIN', 'artistId': '1PKErrAhYFdfrDymGHRQRo', 'genre': 'n/a'}
# Anyone Justin Bieber 31qCy5ZaophVA81wtlwLc4
# {'title': 'Anyone', 'songId': '31qCy5ZaophVA81wtlwLc4', 'artistId': '1uNFoZAHBGtllmzznpCI3s', 'genre': 'canadian pop'}
# Therefore I Am Billie Eilish 54bFM56PmE4YLRnqpW6Tha
# {'title': 'Therefore I Am', 'songId': '54bFM56PmE4YLRnqpW6Tha', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# Higher Power Coldplay 575DkvMbVQ5FXVaNI1o1qN
# {'title': 'Higher Power', 'songId': '575DkvMbVQ5FXVaNI1o1qN', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# BICHOTA KAROL G 1WvrDdouh6C51In1SdATbq
# {'title': 'BICHOTA', 'songId': '1WvrDdouh6C51In1SdATbq', 'artistId': '790FomKkXshlbRYZFtlgla', 'genre': 'reggaeton'}
# Disco Arranhado - Funk Remix Malu, DJ Lucas Beat 3SI736Mng30L5ZTpGEhKEr
# {'title': 'Disco Arranhado - Funk Remix', 'songId': '3SI736Mng30L5ZTpGEhKEr', 'artistId': '3fll16LLw6kdDxWzSpJPEQ', 'genre': 'arrocha'}
# Tout l'univers Gjon's Tears 6hoZwRmLHvUMdQDZGY43Mq
# {'title': "Tout l'univers", 'songId': '6hoZwRmLHvUMdQDZGY43Mq', 'artistId': '0RIwEP1SaALlxn9jOVqHfA', 'genre': 'eurovision'}
# PROBLEMA Daddy Yankee 2dl5K2ScW7jYhAhuem06cm
# {'title': 'PROBLEMA', 'songId': '2dl5K2ScW7jYhAhuem06cm', 'artistId': '4VMYDCV2IEDYJArk749S6m', 'genre': 'latin hip hop'}
# everything i wanted Billie Eilish 3ZCTVFBt2Brf31RLEnCkWJ
# {'title': 'everything i wanted', 'songId': '3ZCTVFBt2Brf31RLEnCkWJ', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# On The Ground ROSÉ 2pn8dNVSpYnAtlKFC8Q0DJ
# {'title': 'On The Ground', 'songId': '2pn8dNVSpYnAtlKFC8Q0DJ', 'artistId': '3eVa5w3URK5duf6eyVDbu9', 'genre': 'k-pop'}
# when the party's over Billie Eilish 43zdsphuZLzwA9k4DJhU0I
# {'title': "when the party's over", 'songId': '43zdsphuZLzwA9k4DJhU0I', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# LOCATION KAROL G, Anuel AA, J Balvin 3yk7PJnryiJ8mAPqsrujzf
# {'title': 'LOCATION', 'songId': '3yk7PJnryiJ8mAPqsrujzf', 'artistId': '699OTQXzgjhIYAHMy9RyPD', 'genre': 'atl hip hop'}
# Afterglow Ed Sheeran 1SymEzIT3H8UZfibCs3TYi
# {'title': 'Afterglow', 'songId': '1SymEzIT3H8UZfibCs3TYi', 'artistId': '06HL4z0CvFAxyc27GXpf02', 'genre': 'pop'}
# Chica Ideal Sebastian Yatra, Guaynaa 0SMTN5XRUlrfXQE0CWu3tE
# {'title': 'Chica Ideal', 'songId': '0SMTN5XRUlrfXQE0CWu3tE', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Gone ROSÉ 1hz7SRTGUNAtIQ46qiNv2p
# {'title': 'Gone', 'songId': '1hz7SRTGUNAtIQ46qiNv2p', 'artistId': '4V8LLVI7PbaPR0K2TGSxFF', 'genre': 'hip hop'}
# Richer (feat. Polo G) Rod Wave 0mehSdTadpXbHAWTrnrIXO
# {'title': 'Richer (feat. Polo G)', 'songId': '0mehSdTadpXbHAWTrnrIXO', 'artistId': '45TgXXqMDdF8BkjA83OM7z', 'genre': 'florida rap'}
# VOCE Madame 5q6CnQ4SdMEp9eaTxsV4n5
# {'title': 'VOCE', 'songId': '5q6CnQ4SdMEp9eaTxsV4n5', 'artistId': '5TGFw78FIV0hLV90O8A7an', 'genre': 'lo-fi jazzhop'}
# 34+35 Remix (feat. Doja Cat, Megan Thee Stallion) - Remix Ariana Grande 2sQH02O2HBCPJCztBrCWNa
# {'title': '34+35 Remix (feat. Doja Cat, Megan Thee Stallion) - Remix', 'songId': '2sQH02O2HBCPJCztBrCWNa', 'artistId': '66CXWjxzNUsdJxJ2JdwvnR', 'genre': 'dance pop'}
# Wonder Shawn Mendes 7ygpwy2qP3NbrxVkHvUhXY
# {'title': 'Wonder', 'songId': '7ygpwy2qP3NbrxVkHvUhXY', 'artistId': '2DaxqgrOhkeH0fpeiQq2f4', 'genre': 'beatlesque'}
# Ay, DiOs Mío! KAROL G 6Cv2svewcHJCj8CrWHUWBK
# {'title': 'Ay, DiOs Mío!', 'songId': '6Cv2svewcHJCj8CrWHUWBK', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Meia Noite (Você tem meu Whatsapp) Tarcísio do Acordeon 5fuK5An5rQcx0OVIzsscOK
# {'title': 'Meia Noite (Você tem meu Whatsapp)', 'songId': '5fuK5An5rQcx0OVIzsscOK', 'artistId': '48HORs6F9P7IgdyKrk4MZC', 'genre': 'arrocha'}
# MODO TURBO Luísa Sonza, Pabllo Vittar, Anitta 2ip4hxYupn3CSsHjn4l2a8
# {'title': 'MODO TURBO', 'songId': '2ip4hxYupn3CSsHjn4l2a8', 'artistId': '4PzYKhC14sTJNEr0dzoo0d', 'genre': 'funk carioca'}
# Amor ou o Litrão Petter Ferraz, Menor Nico 7qmnP8Woc47dLSrMD5MxL1
# {'title': 'Amor ou o Litrão', 'songId': '7qmnP8Woc47dLSrMD5MxL1', 'artistId': '6gGJH7joTDx9M3xREiAq9U', 'genre': 'n/a'}
# Jingle Bell Rock Bobby Helms 7vQbuQcyTflfCIOu3Uzzya
# {'title': 'Jingle Bell Rock', 'songId': '7vQbuQcyTflfCIOu3Uzzya', 'artistId': '38EmEgXkgK51MT2tPY0EoC', 'genre': 'n/a'}
# Sleigh Ride The Ronettes 5ASM6Qjiav2xPe7gRkQMsQ
# {'title': 'Sleigh Ride', 'songId': '5ASM6Qjiav2xPe7gRkQMsQ', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Driving Home for Christmas - 2019 Remaster Chris Rea 2GoiggvbDKJtE2rWrdkfoC
# {'title': 'Driving Home for Christmas - 2019 Remaster', 'songId': '2GoiggvbDKJtE2rWrdkfoC', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Run Rudolph Run - Single Version Chuck Berry 6qgF7oiz11BBipygpNZT2m
# {'title': 'Run Rudolph Run - Single Version', 'songId': '6qgF7oiz11BBipygpNZT2m', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Santa Claus Is Coming To Town The Jackson 5 1Rvi9NP51eGTgA3bSS02Bx
# {'title': 'Santa Claus Is Coming To Town', 'songId': '1Rvi9NP51eGTgA3bSS02Bx', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Christmas (Baby Please Come Home) Darlene Love 3PIDciSFdrQxSQSihim3hN
# {'title': 'Christmas (Baby Please Come Home)', 'songId': '3PIDciSFdrQxSQSihim3hN', 'artistId': '4iHNK0tOyZPYnBU7nGAgpQ', 'genre': 'dance pop'}
# Thank God It's Christmas - Non-Album Single Queen 7edKifcvppw71dHv1uNnlS
# {'title': "Thank God It's Christmas - Non-Album Single", 'songId': '7edKifcvppw71dHv1uNnlS', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Joy To The World Nat King Cole 2ymeOsYijJz09LfKw3yM2x
# {'title': 'Joy To The World', 'songId': '2ymeOsYijJz09LfKw3yM2x', 'artistId': '4FAEZeJcsYYBkNq2D3KGTV', 'genre': 'album rock'}
# What Christmas Means To Me Stevie Wonder 1V0qqWBbIWt8hlAjxTZedR
# {'title': 'What Christmas Means To Me', 'songId': '1V0qqWBbIWt8hlAjxTZedR', 'artistId': '7guDJrEfX3qb6FEbdPA5qi', 'genre': 'funk'}
# Little Saint Nick - 1991 Remix The Beach Boys 5xlS0QkVrSH7ssEbBgBzbM
# {'title': 'Little Saint Nick - 1991 Remix', 'songId': '5xlS0QkVrSH7ssEbBgBzbM', 'artistId': '3oDbviiivRWhXwIE8hxkVV', 'genre': 'baroque pop'}
# Jenny (I Wanna Ruin Our Friendship) Studio Killers 4JLBDUYSaOMPYND0iWeSWQ
# {'title': 'Jenny (I Wanna Ruin Our Friendship)', 'songId': '4JLBDUYSaOMPYND0iWeSWQ', 'artistId': '7avo0PmlW8O1YLEt9DnWQT', 'genre': 'n/a'}
# Agua (with J Balvin) - Music From "Sponge On The Run" Movie Tainy 7CtbxAGq2P0jtYh6SH9DMR
# {'title': 'Agua (with J Balvin) - Music From "Sponge On The Run" Movie', 'songId': '7CtbxAGq2P0jtYh6SH9DMR', 'artistId': '0GM7qgcRCORpGnfcN2tCiB', 'genre': 'latin hip hop'}
# Rojo J Balvin 1FBPEjVf22LmaBm4Z5Kn0W
# {'title': 'Rojo', 'songId': '1FBPEjVf22LmaBm4Z5Kn0W', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# OK Not To Be OK Marshmello, Demi Lovato 0zzVTGyRrWpQu8Fr28NRAv
# {'title': 'OK Not To Be OK', 'songId': '0zzVTGyRrWpQu8Fr28NRAv', 'artistId': '64KEffDW9EtZ1y2vBYgq8T', 'genre': 'brostep'}
# Stunnin' (feat. Harm Franklin) Curtis Waters 2D0dj3hVkRQJCp63cxCPEx
# {'title': "Stunnin' (feat. Harm Franklin)", 'songId': '2D0dj3hVkRQJCp63cxCPEx', 'artistId': '2JbE7jUIGtpXSzytnyMg6U', 'genre': 'n/a'}
# +Linda Dalex 1ahCrpeTt94LL7y1aXw0Y8
# {'title': '+Linda', 'songId': '1ahCrpeTt94LL7y1aXw0Y8', 'artistId': '2p4aN0Uxkk3iT3HK0cJ2cJ', 'genre': 'dominican pop'}
# PORFA Feid, Justin Quiles 2gNNlOPbWBio1bD17qzpYQ
# {'title': 'PORFA', 'songId': '2gNNlOPbWBio1bD17qzpYQ', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# ocean eyes Billie Eilish 7hDVYcQq6MxkdJGweuCtl9
# {'title': 'ocean eyes', 'songId': '7hDVYcQq6MxkdJGweuCtl9', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# Salt Ava Max 4Kd0FzFpOgIGxlBl4HXuFn
# {'title': 'Salt', 'songId': '4Kd0FzFpOgIGxlBl4HXuFn', 'artistId': '44PA0rCQXikgOWbfY7Fq7m', 'genre': 'atl hip hop'}
# Karaoke Boomdabash, Alessandra Amoroso 5bDEA48Dxyxoc3K4Dt7yRE
# {'title': 'Karaoke', 'songId': '5bDEA48Dxyxoc3K4Dt7yRE', 'artistId': '3TVXtAsR1Inumwj472S9r4', 'genre': 'canadian hip hop'}
# Stupid Love Lady Gaga 7yBbV2k2S2uhaQc24NF2xt
# {'title': 'Stupid Love', 'songId': '7yBbV2k2S2uhaQc24NF2xt', 'artistId': '1HY2Jd0NmPuamShAr6KMms', 'genre': 'art pop'}
# Surrender Natalie Taylor 2ccUQnjjNWT0rsNnsBpsCA
# {'title': 'Surrender', 'songId': '2ccUQnjjNWT0rsNnsBpsCA', 'artistId': '1LB8qB5BPb3MHQrfkvifXU', 'genre': 'album rock'}
# In meinem Benz AK AUSSERKONTROLLE, Bonez MC 6BXyD6UUPizpRpA7iOi99r
# {'title': 'In meinem Benz', 'songId': '6BXyD6UUPizpRpA7iOi99r', 'artistId': '07SFzTMeYf5P8Rd32a9Zzw', 'genre': 'german hip hop'}
# Never Seen the Rain Tones And I 5zLnA9bO6QXc4AAvCriJfO
# {'title': 'Never Seen the Rain', 'songId': '5zLnA9bO6QXc4AAvCriJfO', 'artistId': '2NjfBq1NflQcKSeiDooVjY', 'genre': 'australian pop'}
# ANGELS & DEMONS jxdn 3mkz6eI4Sram8UhO3teU76
# {'title': 'ANGELS & DEMONS', 'songId': '3mkz6eI4Sram8UhO3teU76', 'artistId': '6Y64EaNqpqcZYTgs4c76gF', 'genre': 'pop punk'}
# @ MEH Playboi Carti 15JRvf02KKGHKgC31jrpuh
# {'title': '@ MEH', 'songId': '15JRvf02KKGHKgC31jrpuh', 'artistId': '699OTQXzgjhIYAHMy9RyPD', 'genre': 'atl hip hop'}
# BRABA Luísa Sonza 2WlZuBDgLfT7Kc0admhFdg
# {'title': 'BRABA', 'songId': '2WlZuBDgLfT7Kc0admhFdg', 'artistId': '4PzYKhC14sTJNEr0dzoo0d', 'genre': 'funk carioca'}
# Bad Child Tones And I 1qCmZnC1FUpNgOydIzqIPC
# {'title': 'Bad Child', 'songId': '1qCmZnC1FUpNgOydIzqIPC', 'artistId': '2NjfBq1NflQcKSeiDooVjY', 'genre': 'australian pop'}
# bury a friend Billie Eilish 4SSnFejRGlZikf02HLewEF
# {'title': 'bury a friend', 'songId': '4SSnFejRGlZikf02HLewEF', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# Indeciso Reik, J Balvin, Lalo Ebratt 6pgnrn0sjh02kz4PSO3Tf1
# {'title': 'Indeciso', 'songId': '6pgnrn0sjh02kz4PSO3Tf1', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# i love you Billie Eilish 4SqWKzw0CbA05TGszDgMlc
# {'title': 'i love you', 'songId': '4SqWKzw0CbA05TGszDgMlc', 'artistId': '027TpXKGwdXP7iwbjUSpV8', 'genre': 'chicago indie'}
# Forever Yours - Avicii Tribute Kygo, Sandro Cavazza 3o1CUVeHIid49sabk6A6Nf
# {'title': 'Forever Yours - Avicii Tribute', 'songId': '3o1CUVeHIid49sabk6A6Nf', 'artistId': '23fqKkggKUBHNkbKtXEls4', 'genre': 'edm'}
# you should see me in a crown Billie Eilish 3XF5xLJHOQQRbWya6hBp7d
# {'title': 'you should see me in a crown', 'songId': '3XF5xLJHOQQRbWya6hBp7d', 'artistId': '6qqNVTkY8uBg9cP3Jd7DAH', 'genre': 'art pop'}
# Con Calma Daddy Yankee, Snow 5w9c2J52mkdntKOmRLeM2m
# {'title': 'Con Calma', 'songId': '5w9c2J52mkdntKOmRLeM2m', 'artistId': '4VMYDCV2IEDYJArk749S6m', 'genre': 'latin hip hop'}
# King Of My City A Boogie Wit da Hoodie 3o0nkjyy6eZL5lZcEpvJec
# {'title': 'King Of My City', 'songId': '3o0nkjyy6eZL5lZcEpvJec', 'artistId': '31W5EY0aAly4Qieq6OFu6I', 'genre': 'melodic rap'}
# Look At Her Now Selena Gomez 7DJ2vCDCGavdIRdSbj0lid
# {'title': 'Look At Her Now', 'songId': '7DJ2vCDCGavdIRdSbj0lid', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# Into the Unknown Idina Menzel, AURORA 3Z0oQ8r78OUaHvGPiDBR3W
# {'title': 'Into the Unknown', 'songId': '3Z0oQ8r78OUaHvGPiDBR3W', 'artistId': '0LyfQWJT6nXafLPZqxe9Of', 'genre': 'n/a'}
# fuck, i'm lonely (with Anne-Marie) - from “13 Reasons Why: Season 3” Lauv 09PGubKAMryhOWv1LHpCYz
# {'title': "fuck, i'm lonely (with Anne-Marie) - from “13 Reasons Why: Season 3”", 'songId': '09PGubKAMryhOWv1LHpCYz', 'artistId': '5JZ7CnR6gTvEMKX4g70Amv', 'genre': 'electropop'}

# %%
# check successfully paired songs
print(len(pairedSongs))

# check failed songs
print(len(failedSongs)) # do this one manually

# save array as df
df_partial_fix = pd.DataFrame(pairedSongs, columns=['title', 'songId', 'artistId', 'genre'])
df_partial_fix.head()
# Out:
# 85
# 1
#                                        title                  songId  \
# 0  NOT SOBER (feat. Polo G & Stunna Gambino)  1JXBNvlDEl2epKSJ9EOgKX
# 1                              Build a Bitch  7BoobGhD4x5K96Me0hqC8Q
# 2                            Tiroteo - Remix  4OwhwvKESFtuu06dTgct7i
# 3                       Meu Pedaço de Pecado  2kJRlOyrxsy7Ot3c5TZ8Q6
# 4                            Don't Start Now  3PfIrDoz19wz7qK7tYeu62
#
#                  artistId                   genre
# 0  2tIP7SsRs7vjIcLrU85W8J      australian hip hop
# 1  26cMerAxjx9GedFt0lMDjm  modern alternative pop
# 2  5FQ8tBUtIamA2hRtatrYUF             spanish pop
# 3  4JNo6Q5KdcRf1vtSX9mB0S                 arrocha
# 4  6M2wZ9GZgrQXHCFfjv46we               dance pop

# %% [markdown]
# ## Match new data to old data

# %%
# all data in df
# fixed data in df_partial_fix

title_genre_dict = {}

for row in pairedSongs:
        title_genre_dict[row['title']] = row['genre']
            
print(title_genre_dict)
        
missing_mask = df['Genre'].isna()
df.loc[missing_mask, 'Genre'] = df.loc[missing_mask, 'Title'].map(title_genre_dict)

df.head()
# Out:
# {'NOT SOBER (feat. Polo G & Stunna Gambino)': 'australian hip hop', 'Build a Bitch': 'modern alternative pop', 'Tiroteo - Remix': 'spanish pop', 'Meu Pedaço de Pecado': 'arrocha', "Don't Start Now": 'dance pop', 'Dinero': 'n/a', 'Love Again': 'n/a', 'In Da Getto': 'reggaeton', 'No Me Conocen (Remix) [con DUKI, Rei & Tiago PZK]': 'concurso de talentos argentino', 'París': 'pop', 'Sunflower - Spider-Man: Into the Spider-Verse': 'n/a', 'Hold On': 'acoustic pop', 'Aquelas Coisas': 'arrocha', 'Não, Não Vou': 'arrocha', 'Como Si No Importara': 'pop argentino', 'Se For Amor': 'arrocha', 'Ramenez la coupe à la maison': 'francoton', '34+35': 'dance pop', 'bad guy': 'art pop', 'As the World Caves In': 'gen z singer-songwriter', 'Chosen (feat. Ty Dolla $ign)': 'pop rap', 'Lost Cause': 'art pop', 'Dick (feat. Doja Cat)': 'n/a', 'malibu': 'dance pop', 'Wellerman - Sea Shanty / 220 KID x Billen Ted Remix': 'n/a', 'Anyone': 'canadian pop', 'Therefore I Am': 'art pop', 'Higher Power': 'n/a', 'BICHOTA': 'reggaeton', 'Disco Arranhado - Funk Remix': 'arrocha', "Tout l'univers": 'eurovision', 'PROBLEMA': 'latin hip hop', 'everything i wanted': 'art pop', 'On The Ground': 'k-pop', "when the party's over": 'art pop', 'LOCATION': 'atl hip hop', 'Afterglow': 'pop', 'Chica Ideal': 'n/a', 'Gone': 'hip hop', 'Richer (feat. Polo G)': 'florida rap', 'VOCE': 'lo-fi jazzhop', '34+35 Remix (feat. Doja Cat, Megan Thee Stallion) - Remix': 'dance pop', 'Wonder': 'beatlesque', 'Ay, DiOs Mío!': 'n/a', 'Meia Noite (Você tem meu Whatsapp)': 'arrocha', 'MODO TURBO': 'funk carioca', 'Amor ou o Litrão': 'n/a', 'Jingle Bell Rock': 'n/a', 'Sleigh Ride': 'n/a', 'Driving Home for Christmas - 2019 Remaster': 'n/a', 'Run Rudolph Run - Single Version': 'n/a', 'Santa Claus Is Coming To Town': 'n/a', 'Christmas (Baby Please Come Home)': 'dance pop', "Thank God It's Christmas - Non-Album Single": 'n/a', 'Joy To The World': 'album rock', 'What Christmas Means To Me': 'funk', 'Little Saint Nick - 1991 Remix': 'baroque pop', 'Jenny (I Wanna Ruin Our Friendship)': 'n/a', 'Agua (with J Balvin) - Music From "Sponge On The Run" Movie': 'latin hip hop', 'Rojo': 'n/a', 'OK Not To Be OK': 'brostep', "Stunnin' (feat. Harm Franklin)": 'n/a', '+Linda': 'dominican pop', 'PORFA': 'n/a', 'ocean eyes': 'art pop', 'Salt': 'atl hip hop', 'Karaoke': 'canadian hip hop', 'Stupid Love': 'art pop', 'Surrender': 'album rock', 'In meinem Benz': 'german hip hop', 'Never Seen the Rain': 'australian pop', 'ANGELS & DEMONS': 'pop punk', '@ MEH': 'atl hip hop', 'BRABA': 'funk carioca', 'Bad Child': 'australian pop', 'bury a friend': 'art pop', 'Indeciso': 'n/a', 'i love you': 'chicago indie', 'Forever Yours - Avicii Tribute': 'edm', 'you should see me in a crown': 'art pop', 'Con Calma': 'latin hip hop', 'King Of My City': 'melodic rap', 'Look At Her Now': 'n/a', 'Into the Unknown': 'n/a', "fuck, i'm lonely (with Anne-Marie) - from “13 Reasons Why: Season 3”": 'electropop'}
#                                            Title      Artist        Genre  \
# 0                  STARSTRUKK (feat. Katy Perry)       3OH!3    dance pop
# 1                    My First Kiss (feat. Ke$ha)       3OH!3    dance pop
# 2                                I Need A Dollar  Aloe Blacc     pop soul
# 3  Airplanes (feat. Hayley Williams of Paramore)       B.o.B  atl hip hop
# 4              Nothin' on You (feat. Bruno Mars)       B.o.B  atl hip hop
#
#   Release Date  Popularity  Danceability  dnce(raw ignore)  Energy  \
# 0         2009        70.0          0.61              61.0    0.81
# 1         2010        68.0          0.68              68.0    0.89
# 2         2010        72.0          0.84              84.0    0.48
# 3         2010        80.0          0.66              66.0    0.87
# 4         2010        79.0          0.69              69.0    0.85
#
#    nrgy(raw ignore)  Loudness (dB)  ...  Acousticness  acous(ignore)  \
# 0              81.0           -6.0  ...          0.00            0.0
# 1              89.0           -4.0  ...          0.01            1.0
# 2              48.0           -7.0  ...          0.20           20.0
# 3              87.0           -4.0  ...          0.11           11.0
# 4              85.0           -6.0  ...          0.39           39.0
#
#    Liveness    BPM  Duration (ms)  dur (ignore)  Valence  val(ignore)  \
# 0      23.0  140.0       203000.0         203.0     0.23         23.0
# 1      36.0  138.0       192000.0         192.0     0.83         83.0
# 2       9.0   95.0       243000.0         243.0     0.96         96.0
# 3       4.0   93.0       180000.0         180.0     0.38         38.0
# 4       9.0  104.0       268000.0         268.0     0.74         74.0
#
#    Top Year (ignore)  Top Year
# 0               2010      2010
# 1               2010      2010
# 2               2010      2010
# 3               2010      2010
# 4               2010      2010
#
# [5 rows x 22 columns]

# %%
df.to_csv("fixed_data.csv")
